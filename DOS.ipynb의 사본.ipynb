# %% [markdown]
# 1. 새로 project 폴더 만들고 그 안의 파일을 github에 올리고 싶을때 가장 먼저 .gitignore를 만들고 올려줘야함

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/My Drive/Colab Notebooks/2020-TAVE-ML-Practice-Study/')
# !pwd # 경로확인 /content/gdrive/My Drive/Colab Notebooks/gan_project
# !git init #Initialized empty Git repository in /content/gdrive/My Drive/Colab Notebooks/gan_project/.git/
# Out:
# /content/gdrive/My Drive/Colab Notebooks/2020-TAVE-ML-Practice-Study
# Initialized empty Git repository in /content/gdrive/My Drive/Colab Notebooks/2020-TAVE-ML-Practice-Study/.git/

# %%
# !git config --global user.email "dbj2000@naver.com"
# !git config --global user.name "dbj2000"
# !git add . #현재 디렉토리 모든 파일을 stage올린다. -> 전부 업로드한다는 의미.
# !git add proj2_GAN.ipynb
# !git commit -m "init_only_notebook"
# !git remote add origin https://github.com/dbj2000/2020-TAVE-ML-Practice-Study.git
# !git push
# !git push -u origin master
# Out:
# [master 7ef1a29] init_only_notebook
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite "DOS.ipynb\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253.ipynb" (80%)
# fatal: remote origin already exists.
# fatal: The current branch master has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin master
#
# fatal: unable to access 'https://dbj2000:wlsgusdud131@github.com/dbj2000/레포지토리명.git/': The requested URL returned error: 400

# %% [markdown]
# 2. 작업하던 폴더에서 파일 수정하고 git에 수정 결과 올리기

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/My Drive/Colab Notebooks/2020-Generative-Deep-Learning-Study/')
# !pwd # 경로확인 /content/gdrive/My Drive/Colab Notebooks/gan_project
# Out:
# /content/gdrive/My Drive/Colab Notebooks/2020-Generative-Deep-Learning-Study

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	deleted:    .gitignore
# 	deleted:    proj1_VAE/model/pokemon_vae_param.pt
# 	deleted:    proj1_VAE/proj1_VAE_keras.ipynb
# 	deleted:    proj1_VAE/proj1_VAE_pytorch.ipynb
# 	deleted:    proj2_GAN/proj2_GAN.ipynb
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	.gitignore
# 	proj1_VAE/
# 	proj2_GAN/
# 	proj3_Advanced_VAE/

# %%
# !git add .

# %%
# !rm -f ./.git/index.lock

# %%
# !git commit -m "new vae"
# Out:
# [master 82134b9] new vae
#  1 file changed, 1 insertion(+)
#  create mode 100644 proj3_Advanced_VAE/proj3_advanced_VAE_pytorch.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 4.71 KiB | 965.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/dbj2000/2020-Generative-Deep-Learning-Study.git
#    1efee67..82134b9  master -> master

# %%
# !git config --global user.email "dbj2000@naver.com"
# !git config --global user.name "dbj2000"
